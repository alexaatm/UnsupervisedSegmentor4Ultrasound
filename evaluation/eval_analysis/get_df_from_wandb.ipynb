# %%
import pandas as pd 
import wandb
api = wandb.Api()
import json

# %%
# Project is specified by <entity/project-name>
runs = api.runs(path="alexaatm/segm-eval",
    filters={
        "$and":[
            {"config.dataset.name": "mutinfo_val_carotid"},
            {"State": "finished"},
            {"tags": {"$in": ["majority_vote_unique", "rerun_after_bugfix", "cutler"]}},
        ]
    }
    )

# %%
summary_list, config_list, name_list, run_ids, logged_artifacts = [], [], [], [], []
for run in runs: 
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append(
        {k: v for k,v in run.config.items()
          if not k.startswith('_')})

    # .name is the human-readable name of the run.
    name_list.append(run.name)
    run_ids.append(run.id)
    logged_artifacts.append(run.logged_artifacts())

# %%
runs_df = pd.DataFrame({
    "summary": summary_list,
    "config": config_list,
    "name": name_list,
    "run_id": run_ids,
    "logged_artifacts": logged_artifacts
    })

# runs_df.to_csv("project.csv")

# %%
run.config['dataset']['name']
# Out:
# 'mutinfo_val_carotid'

# %%
# Extract only some fields
dataset_pred_dir_list, eval_per_image_list, iou_thresh_list, miou_list, jacc_class0_list, jacc_class1_list, name_list, run_ids = [], [], [], [], [], [], [], []
for run in runs: 
    dataset_pred_dir_list.append(run.config['dataset']['pred_dir'])

    eval_per_image_list.append(run.config['eval_per_image'])

    iou_thresh_list.append(run.config['iou_thresh'])


    miou_list.append(run.summary['mIoU'])


    # get logged artifacts
    artifacts = run.logged_artifacts()
    jacc_table_artifact = [artifact for artifact in artifacts if "jaccard_table" in artifact.name][0]
    table_dir = jacc_table_artifact.download()
    table_path = f"{table_dir}/jaccard_table.table.json"
    jacc_table = json.load(open(table_path))
    df = pd.DataFrame(jacc_table["data"], columns=jacc_table["columns"])    

    jacc_class0_list.append(df['GT_class0'].iloc[0])
    jacc_class1_list.append(df['GT_class1'].iloc[0])

    # .name is the human-readable name of the run.
    name_list.append(run.name)
    run_ids.append(run.id)
# Out:
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.

# %%
runs_df = pd.DataFrame({
    "pred_dir": dataset_pred_dir_list,
    "eval_per_image": eval_per_image_list,
    "iou_thresh": iou_thresh_list,
    "mIoU": miou_list,
    "jacc_class0": jacc_class0_list,
    "jacc_class1": jacc_class1_list,
    "name": name_list,
    "id": run_ids
    })

# %%
runs_df.head()
# Out:
#                                             pred_dir  eval_per_image  \
# 0  /home/guests/oleksandra_tmenova/test/project/t...           False
# 1  /home/guests/oleksandra_tmenova/test/project/t...           False
# 2  /home/guests/oleksandra_tmenova/test/project/t...           False
# 3  /home/guests/oleksandra_tmenova/test/project/t...           False
# 4  /home/guests/oleksandra_tmenova/test/project/t...           False
#
#    iou_thresh      mIoU  jacc_class0  jacc_class1  \
# 0         0.0  0.577858     0.968323     0.187394
# 1         0.0  0.482332     0.924374     0.040291
# 2         0.0  0.534590     0.921120     0.148059
# 3         0.0  0.473247     0.916690     0.029804
# 4         0.0  0.471869     0.914620     0.029118
#
#                                            name        id
# 0  eval_mutinfo_val_carotid_2023-09-13_01-11-40  qgmq01wp
# 1  eval_mutinfo_val_carotid_2023-09-13_01-11-40  hgwtxx9v
# 2  eval_mutinfo_val_carotid_2023-09-12_17-56-15  lbuhs11i
# 3  eval_mutinfo_val_carotid_2023-09-12_17-56-15  e6pgp6qj
# 4  eval_mutinfo_val_carotid_2023-09-12_17-56-15  58lz5umy

# %%
grouped = runs_df.groupby('pred_dir')

# %%
from tabulate import tabulate

# %%
# Define a function to extract additional columns from 'pred_dir'
def extract_info(pred_dir):
    if pred_dir=="/home/guests/oleksandra_tmenova/test/project/thesis-codebase/deep-spectral-segmentation/outputs/pipeline/mutinfo_val_carotid/2023-08-14--13-59-23/semantic_segmentations/laplacian/crf_segmaps":
        series = pd.Series(["dino", 15, "crf_segmaps"], index=['features', 'n_clusters', 'prediction'])
    elif pred_dir=="/home/guests/oleksandra_tmenova/test/project/thesis-codebase/deep-spectral-segmentation/outputs/pipeline/mutinfo_val_carotid/2023-08-13--20-47-28/semantic_segmentations/laplacian/crf_multi_region":
        series = pd.Series(["dino", 15, "crf_multi_region"], index=['features', 'n_clusters', 'prediction'])
    elif pred_dir == "/home/guests/oleksandra_tmenova/test/project/thesis-codebase/deep-spectral-segmentation/outputs/pipeline/mutinfo_val_carotid/2023-08-16--18-13-13/semantic_segmentations/laplacian/crf_segmaps":
        series = pd.Series(["dino_ssd1", 15, "crf_segmaps"], index=['features', 'n_clusters', 'prediction'])
    elif pred_dir == "/home/guests/oleksandra_tmenova/test/project/thesis-codebase/deep-spectral-segmentation/outputs/pipeline/mutinfo_val_carotid/2023-08-16--18-13-13/semantic_segmentations/laplacian/crf_multi_region":
        series = pd.Series(["dino_ssd1", 15, "crf_multi_region"], index=['features', 'n_clusters', 'prediction'])
    elif pred_dir == "/home/guests/oleksandra_tmenova/test/project/thesis-codebase/deep-spectral-segmentation/outputs/pipeline/mutinfo_val_carotid/2023-08-16--22-45-22/semantic_segmentations/laplacian/crf_segmaps":
        series = pd.Series(["dino_ssd2", 15, "crf_segmaps"], index=['features', 'n_clusters', 'prediction'])
    elif pred_dir == "/home/guests/oleksandra_tmenova/test/project/thesis-codebase/deep-spectral-segmentation/outputs/pipeline/mutinfo_val_carotid/2023-08-16--22-45-22/semantic_segmentations/laplacian/crf_multi_region":
        series = pd.Series(["dino_ssd2", 15, "crf_multi_region"], index=['features', 'n_clusters', 'prediction'])
    
    n_clusters = None
    features = None
    prediction_type = None
    
    # Check for "clusters" in the prediction directory
    if "clusters" in pred_dir:
        # Extract n_clusters using string manipulation
        start = pred_dir.index("clusters") + len("clusters")
        end = pred_dir.index("_", start)
        n_clusters = int(pred_dir[start:end])

    # Check for "dino" in the prediction directory
    if "dino" in pred_dir:
        features = "dino"
        if "ssd1" in pred_dir:
            features += "_ssd1"
        elif "ssd2" in pred_dir:
            features += "_ssd2"
    elif "cutler" in pred_dir:
        features = "cutler"
        if "imagenet" in pred_dir:
            features += "imagenet"
        elif "cutler_carotid" in pred_dir:
            features += 
        elif "maskcut_init" in pred_dir:
            features += "maskcut_init"
        elif "maskcut"

    # Extract prediction_type
    if "crf_segmaps" in pred_dir:
        prediction_type = "crf_segmaps"
    elif "crf_multi_region" in pred_dir:
        prediction_type = "crf_multi_region"

    series = pd.Series([features, n_clusters, prediction_type], index=['features', 'n_clusters', 'prediction'])
    

    # Modify this function to extract 'features', 'n_clusters', and 'prediction'
    # features = "only_dino" if "only_dino" in pred_dir else "other"
    # n_clusters = int(pred_dir.split("_")[-1])
    # prediction = "crf_segmaps" if "crf_segmaps" in pred_dir else "other_prediction"
    return series

# Apply the function and add columns to the DataFrame
runs_df[['features', 'n_clusters', 'prediction']] = runs_df['pred_dir'].apply(extract_info)

# %%
runs_df
# Out:
#                                              pred_dir  eval_per_image  \
# 0   /home/guests/oleksandra_tmenova/test/project/t...           False
# 1   /home/guests/oleksandra_tmenova/test/project/t...           False
# 2   /home/guests/oleksandra_tmenova/test/project/t...           False
# 3   /home/guests/oleksandra_tmenova/test/project/t...           False
# 4   /home/guests/oleksandra_tmenova/test/project/t...           False
# 5   /home/guests/oleksandra_tmenova/test/project/t...           False
# 6   /home/guests/oleksandra_tmenova/test/project/t...            True
# 7   /home/guests/oleksandra_tmenova/test/project/t...            True
# 8   /home/guests/oleksandra_tmenova/test/project/t...            True
# 9   /home/guests/oleksandra_tmenova/test/project/t...            True
# 10  /home/guests/oleksandra_tmenova/test/project/t...            True
# 11  /home/guests/oleksandra_tmenova/test/project/t...           False
# 12  /home/guests/oleksandra_tmenova/test/project/t...           False
# 13  /home/guests/oleksandra_tmenova/test/project/t...            True
# 14  /home/guests/oleksandra_tmenova/test/project/t...            True
# 15  /home/guests/oleksandra_tmenova/test/project/t...           False
# 16  /home/guests/oleksandra_tmenova/test/project/t...           False
# 17  /home/guests/oleksandra_tmenova/test/project/t...            True
# 18  /home/guests/oleksandra_tmenova/test/project/t...            True
# 19  /home/guests/oleksandra_tmenova/test/project/t...           False
# 20  /home/guests/oleksandra_tmenova/test/project/t...           False
# 21  /home/guests/oleksandra_tmenova/test/project/t...            True
# 22  /home/guests/oleksandra_tmenova/test/project/t...           False
# 23  /home/guests/oleksandra_tmenova/test/project/t...           False
# 24  /home/guests/oleksandra_tmenova/test/project/t...           False
# 25  /home/guests/oleksandra_tmenova/test/project/t...           False
# 26  /home/guests/oleksandra_tmenova/test/project/t...           False
# 27  /home/guests/oleksandra_tmenova/test/project/t...           False
# 28  /home/guests/oleksandra_tmenova/test/project/t...           False
# 29  /home/guests/oleksandra_tmenova/test/project/t...           False
# 30  /home/guests/oleksandra_tmenova/test/project/t...           False
# 31  /home/guests/oleksandra_tmenova/test/project/t...           False
# 32  /home/guests/oleksandra_tmenova/test/project/t...           False
# 33  /home/guests/oleksandra_tmenova/test/project/t...           False
# 34  /home/guests/oleksandra_tmenova/test/project/t...           False
# 35  /home/guests/oleksandra_tmenova/test/project/t...           False
# 36  /home/guests/oleksandra_tmenova/test/project/t...           False
# 37  /home/guests/oleksandra_tmenova/test/project/t...           False
# 38  /home/guests/oleksandra_tmenova/test/project/t...           False
# 39  /home/guests/oleksandra_tmenova/test/project/t...           False
# 40  /home/guests/oleksandra_tmenova/test/project/t...            True
# 41  /home/guests/oleksandra_tmenova/test/project/t...            True
# 42  /home/guests/oleksandra_tmenova/test/project/t...            True
# 43  /home/guests/oleksandra_tmenova/test/project/t...            True
# 44  /home/guests/oleksandra_tmenova/test/project/t...            True
# 45  /home/guests/oleksandra_tmenova/test/project/t...            True
# 46  /home/guests/oleksandra_tmenova/test/project/t...            True
# 47  /home/guests/oleksandra_tmenova/test/project/t...            True
# 48  /home/guests/oleksandra_tmenova/test/project/t...            True
# 49  /home/guests/oleksandra_tmenova/test/project/t...            True
# 50  /home/guests/oleksandra_tmenova/test/project/t...            True
# 51  /home/guests/oleksandra_tmenova/test/project/t...            True
#
#     iou_thresh      mIoU  jacc_class0  jacc_class1  \
# 0          0.0  0.577858     0.968323     0.187394
# 1          0.0  0.482332     0.924374     0.040291
# 2          0.0  0.534590     0.921120     0.148059
# 3          0.0  0.473247     0.916690     0.029804
# 4          0.0  0.471869     0.914620     0.029118
# 5          0.0  0.513261     0.880976     0.145545
# 6          0.0  0.277633     0.509845     0.045421
# 7          0.0  0.600312     0.957502     0.243121
# 8          0.0  0.407995     0.749443     0.066546
# 9          0.0  0.277633     0.509845     0.045421
# 10         0.0  0.196059     0.354972     0.037145
# 11         0.0  0.494523     0.956013     0.033033
# 12         0.0  0.490374     0.916493     0.064255
# 13         0.0  0.288938     0.523367     0.054508
# 14         0.0  0.217387     0.406554     0.028219
# 15         0.0  0.334890     0.623952     0.045829
# 16         0.0  0.483214     0.936892     0.029535
# 17         0.0  0.672208     0.968655     0.375761
# 18         0.0  0.512967     0.946574     0.079360
# 19         0.0  0.482932     0.941582     0.024282
# 20         0.0  0.373823     0.699664     0.047982
# 21         0.0  0.312962     0.568762     0.057162
# 22         0.0  0.479765     0.899945     0.059585
# 23         0.0  0.544318     0.961593     0.127043
# 24         0.0  0.474805     0.896431     0.053178
# 25         0.0  0.216249     0.397322     0.035176
# 26         0.0  0.475689     0.914976     0.036402
# 27         0.0  0.482749     0.914907     0.050591
# 28         0.5  0.350834     0.700100     0.001568
# 29         0.5  0.290798     0.576099     0.005496
# 30         0.0  0.497422     0.945101     0.049743
# 31         0.0  0.561639     0.973450     0.149827
# 32         0.5  0.264943     0.522603     0.007284
# 33         0.5  0.376668     0.752283     0.001053
# 34         0.0  0.542428     0.944299     0.140557
# 35         0.5  0.350823     0.695406     0.006239
# 36         0.0  0.491897     0.933176     0.050617
# 37         0.0  0.652332     0.974484     0.330181
# 38         0.5  0.331705     0.659396     0.004014
# 39         0.0  0.486643     0.927540     0.045747
# 40         0.5  0.578705     0.938911     0.218499
# 41         0.5  0.375697     0.719467     0.031927
# 42         0.5  0.394376     0.762091     0.026661
# 43         0.0  0.620372     0.949850     0.290895
# 44         0.0  0.539297     0.913491     0.165103
# 45         0.5  0.431331     0.810194     0.052468
# 46         0.0  0.552896     0.909543     0.196248
# 47         0.5  0.343498     0.658805     0.028191
# 48         0.0  0.760646     0.983943     0.537348
# 49         0.0  0.788242     0.986232     0.590251
# 50         0.0  0.594708     0.953321     0.236096
# 51         0.5  0.541848     0.919400     0.164296
#
#                                             name        id   features  \
# 0   eval_mutinfo_val_carotid_2023-09-13_01-11-40  qgmq01wp  dino_ssd2
# 1   eval_mutinfo_val_carotid_2023-09-13_01-11-40  hgwtxx9v  dino_ssd2
# 2   eval_mutinfo_val_carotid_2023-09-12_17-56-15  lbuhs11i  dino_ssd1
# 3   eval_mutinfo_val_carotid_2023-09-12_17-56-15  e6pgp6qj  dino_ssd2
# 4   eval_mutinfo_val_carotid_2023-09-12_17-56-15  58lz5umy  dino_ssd1
# 5   eval_mutinfo_val_carotid_2023-09-12_17-56-15  1hhre3zw  dino_ssd2
# 6   eval_mutinfo_val_carotid_2023-09-09_14-44-24  nh3cr4wl       None
# 7   eval_mutinfo_val_carotid_2023-09-09_14-26-07  h4apkbcq       None
# 8   eval_mutinfo_val_carotid_2023-09-09_14-02-58  xm0id29p       None
# 9   eval_mutinfo_val_carotid_2023-09-09_13-38-34  mz7gzg9g       None
# 10  eval_mutinfo_val_carotid_2023-09-09_13-27-31  tvfqr1d4       None
# 11  eval_mutinfo_val_carotid_2023-09-07_11-55-28  1pj825ou       None
# 12  eval_mutinfo_val_carotid_2023-09-04_13-46-44  b1hohjzz       None
# 13  eval_mutinfo_val_carotid_2023-09-04_13-43-19  7gr7mks8       None
# 14  eval_mutinfo_val_carotid_2023-09-04_13-29-46  8116t4lm       None
# 15  eval_mutinfo_val_carotid_2023-09-04_13-26-49  tt114leh       None
# 16  eval_mutinfo_val_carotid_2023-08-30_16-49-45  ul6cqsvr       None
# 17  eval_mutinfo_val_carotid_2023-08-30_16-49-45  pd886r7h       None
# 18  eval_mutinfo_val_carotid_2023-08-30_15-40-04  z7h5w5wb       None
# 19  eval_mutinfo_val_carotid_2023-08-30_15-40-04  hx819d7s       None
# 20  eval_mutinfo_val_carotid_2023-08-29_20-42-06  xvx05t7h       None
# 21  eval_mutinfo_val_carotid_2023-08-29_20-42-06  sos7xbob       None
# 22  eval_mutinfo_val_carotid_2023-08-24_11-18-41  r0ahr8l4  dino_ssd1
# 23  eval_mutinfo_val_carotid_2023-08-24_11-18-41  o27ez3ia  dino_ssd1
# 24  eval_mutinfo_val_carotid_2023-08-24_11-18-41  i92javyq  dino_ssd2
# 25  eval_mutinfo_val_carotid_2023-08-24_11-18-41  5my3z9is       dino
# 26  eval_mutinfo_val_carotid_2023-08-24_11-18-41  5d6vho1a  dino_ssd2
# 27  eval_mutinfo_val_carotid_2023-08-24_11-18-41  0v79dkc3       dino
# 28  eval_mutinfo_val_carotid_2023-08-23_12-14-00  la706285       None
# 29  eval_mutinfo_val_carotid_2023-08-23_12-13-56  vg2qzc70       None
# 30  eval_mutinfo_val_carotid_2023-08-23_12-13-56  vdet1hhi       None
# 31  eval_mutinfo_val_carotid_2023-08-23_12-13-56  phw1k3xn       None
# 32  eval_mutinfo_val_carotid_2023-08-23_12-13-56  km0yaq6i       None
# 33  eval_mutinfo_val_carotid_2023-08-23_12-13-56  jumfd98z       None
# 34  eval_mutinfo_val_carotid_2023-08-23_12-13-56  ghsl6heg       None
# 35  eval_mutinfo_val_carotid_2023-08-23_12-13-56  aznxkeaq       None
# 36  eval_mutinfo_val_carotid_2023-08-23_12-13-56  8nagf3vu       None
# 37  eval_mutinfo_val_carotid_2023-08-23_12-13-56  4dqqjk1p       None
# 38  eval_mutinfo_val_carotid_2023-08-23_12-13-56  3aaun7jg       None
# 39  eval_mutinfo_val_carotid_2023-08-23_12-13-56  2qhhvb01       None
# 40  eval_mutinfo_val_carotid_2023-08-23_11-08-57  zzdv67gd       None
# 41  eval_mutinfo_val_carotid_2023-08-23_11-08-21  st00ykkw       None
# 42  eval_mutinfo_val_carotid_2023-08-23_11-08-21  rsh5v3t5       None
# 43  eval_mutinfo_val_carotid_2023-08-23_11-08-21  q9sah23p       None
# 44  eval_mutinfo_val_carotid_2023-08-23_11-08-21  npzwlzk5       None
# 45  eval_mutinfo_val_carotid_2023-08-23_11-08-21  hoef0lyh       None
# 46  eval_mutinfo_val_carotid_2023-08-23_11-08-21  a7n2maly       None
# 47  eval_mutinfo_val_carotid_2023-08-23_11-08-21  7p4hfryl       None
# 48  eval_mutinfo_val_carotid_2023-08-23_11-08-21  6uop5kqz       None
# 49  eval_mutinfo_val_carotid_2023-08-23_11-08-21  5zis1cn1       None
# 50  eval_mutinfo_val_carotid_2023-08-23_11-08-21  5b062zuq       None
# 51  eval_mutinfo_val_carotid_2023-08-23_11-08-21  2o9640mp       None
#
#     n_clusters        prediction
# 0         15.0       crf_segmaps
# 1         15.0  crf_multi_region
# 2         15.0       crf_segmaps
# 3         15.0  crf_multi_region
# 4         15.0  crf_multi_region
# 5         15.0       crf_segmaps
# 6          NaN              None
# 7          NaN              None
# 8          NaN              None
# 9          NaN              None
# 10         NaN              None
# 11         NaN              None
# 12         NaN              None
# 13         NaN              None
# 14         NaN              None
# 15         NaN              None
# 16         NaN              None
# 17         NaN              None
# 18         NaN              None
# 19         NaN              None
# 20         NaN              None
# 21         NaN              None
# 22         6.0  crf_multi_region
# 23         6.0       crf_segmaps
# 24         6.0  crf_multi_region
# 25         6.0       crf_segmaps
# 26         6.0       crf_segmaps
# 27         6.0  crf_multi_region
# 28         NaN  crf_multi_region
# 29         NaN  crf_multi_region
# 30         NaN  crf_multi_region
# 31         NaN       crf_segmaps
# 32         NaN       crf_segmaps
# 33         NaN  crf_multi_region
# 34         NaN       crf_segmaps
# 35         NaN       crf_segmaps
# 36         NaN  crf_multi_region
# 37         NaN       crf_segmaps
# 38         NaN       crf_segmaps
# 39         NaN  crf_multi_region
# 40         NaN  crf_multi_region
# 41         NaN  crf_multi_region
# 42         NaN       crf_segmaps
# 43         NaN       crf_segmaps
# 44         NaN       crf_segmaps
# 45         NaN       crf_segmaps
# 46         NaN       crf_segmaps
# 47         NaN       crf_segmaps
# 48         NaN  crf_multi_region
# 49         NaN  crf_multi_region
# 50         NaN  crf_multi_region
# 51         NaN  crf_multi_region

# %%
grouped_by_features = runs_df.groupby('features')
# Dictionary to store DataFrames for each group
grouped_df = {}

# Iterate through the groups and print the relevant information
for feature, group_data in grouped_by_features:
    print(f"Group: {feature}")
    # Sort the group by 'jacc_class1' column in descending order
    sorted_group = group_data.sort_values(by=['eval_per_image', 'prediction', 'iou_thresh', 'jacc_class1'], ascending=[False, False, True, False])

    grouped_df[feature] = sorted_group[['eval_per_image','prediction', 'iou_thresh','jacc_class0', 'jacc_class1', 'mIoU','n_clusters',]]

    # print(sorted_group[['prediction', 'n_clusters','eval_per_image', 'iou_thresh', 'mIoU', 'jacc_class0', 'jacc_class1']])
    # print("\n")
# Out:
# Group: dino
# Group: dino_ssd1
# Group: dino_ssd2

# %%
grouped_df['dino']
# Out:
#     eval_per_image        prediction  iou_thresh  jacc_class0  jacc_class1  \
# 25           False       crf_segmaps         0.0     0.397322     0.035176
# 27           False  crf_multi_region         0.0     0.914907     0.050591
#
#         mIoU  n_clusters
# 25  0.216249         6.0
# 27  0.482749         6.0

# %%
def bold_rows(row, column, sign, value):
    if sign==">":
        return ['font-weight: bold' if row[column] > value else '' for _ in row]
    elif sign=="<":
        return ['font-weight: bold' if row[column] < value else '' for _ in row]

# %%
# Define a function to apply bold style to the row with the maximum value in a specified column
def bold_max_row(series):
    max_index = series.idxmax()
    return ['font-weight: bold' if idx == max_index else '' for idx in df.index]

# %%
styled_df = grouped_df['dino'].style.apply(bold_rows, column='jacc_class1', sign=">", value=0.2, axis=1)
# styled_df = grouped_df['dino'].style.apply(bold_max_row, subset=['jacc_class1'])

# %%
styled_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_6eafe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6eafe_level0_col0" class="col_heading level0 col0" >eval_per_image</th>
#       <th id="T_6eafe_level0_col1" class="col_heading level0 col1" >prediction</th>
#       <th id="T_6eafe_level0_col2" class="col_heading level0 col2" >iou_thresh</th>
#       <th id="T_6eafe_level0_col3" class="col_heading level0 col3" >jacc_class0</th>
#       <th id="T_6eafe_level0_col4" class="col_heading level0 col4" >jacc_class1</th>
#       <th id="T_6eafe_level0_col5" class="col_heading level0 col5" >mIoU</th>
#       <th id="T_6eafe_level0_col6" class="col_heading level0 col6" >n_clusters</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6eafe_level0_row0" class="row_heading level0 row0" >25</th>
#       <td id="T_6eafe_row0_col0" class="data row0 col0" >False</td>
#       <td id="T_6eafe_row0_col1" class="data row0 col1" >crf_segmaps</td>
#       <td id="T_6eafe_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_6eafe_row0_col3" class="data row0 col3" >0.397322</td>
#       <td id="T_6eafe_row0_col4" class="data row0 col4" >0.035176</td>
#       <td id="T_6eafe_row0_col5" class="data row0 col5" >0.216249</td>
#       <td id="T_6eafe_row0_col6" class="data row0 col6" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6eafe_level0_row1" class="row_heading level0 row1" >27</th>
#       <td id="T_6eafe_row1_col0" class="data row1 col0" >False</td>
#       <td id="T_6eafe_row1_col1" class="data row1 col1" >crf_multi_region</td>
#       <td id="T_6eafe_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_6eafe_row1_col3" class="data row1 col3" >0.914907</td>
#       <td id="T_6eafe_row1_col4" class="data row1 col4" >0.050591</td>
#       <td id="T_6eafe_row1_col5" class="data row1 col5" >0.482749</td>
#       <td id="T_6eafe_row1_col6" class="data row1 col6" >6.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# GROUP BY EVALUATION

# %%
grouped_by_eval = runs_df.groupby(['eval_per_image',  'iou_thresh'])
# Dictionary to store DataFrames for each group
df_by_eval = {}

# Iterate through the groups and print the relevant information
for eval, group_data in grouped_by_eval:
    print(f"Group: {eval}")
    # Sort the group by 'jacc_class1' column in descending order
    sorted_group = group_data.sort_values(by=['features','prediction','jacc_class1'], ascending=[True, True, True])

    df_by_eval[eval] = sorted_group[['eval_per_image', 'iou_thresh','features','n_clusters','prediction','jacc_class0', 'jacc_class1', 'mIoU',]]

    print(type(eval))

    # print(sorted_group[['prediction', 'n_clusters','eval_per_image', 'iou_thresh', 'mIoU', 'jacc_class0', 'jacc_class1']])
    # print("\n")
# Out:
# Group: (False, 0.0)
# <class 'tuple'>
# Group: (False, 0.5)
# <class 'tuple'>
# Group: (True, 0.0)
# <class 'tuple'>
# Group: (True, 0.5)
# <class 'tuple'>

# %%
df_by_eval[(False, 0.0)]
styled_df = df_by_eval[(False, 0.0)].style.apply(bold_rows, column='jacc_class1', sign=">", value=0.2, axis=1)
styled_df
# Out:
# <style type="text/css">
# #T_c0cf8_row17_col0, #T_c0cf8_row17_col1, #T_c0cf8_row17_col2, #T_c0cf8_row17_col3, #T_c0cf8_row17_col4, #T_c0cf8_row17_col5, #T_c0cf8_row17_col6, #T_c0cf8_row17_col7 {
#   font-weight: bold;
# }
# </style>
# <table id="T_c0cf8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0cf8_level0_col0" class="col_heading level0 col0" >eval_per_image</th>
#       <th id="T_c0cf8_level0_col1" class="col_heading level0 col1" >iou_thresh</th>
#       <th id="T_c0cf8_level0_col2" class="col_heading level0 col2" >features</th>
#       <th id="T_c0cf8_level0_col3" class="col_heading level0 col3" >n_clusters</th>
#       <th id="T_c0cf8_level0_col4" class="col_heading level0 col4" >prediction</th>
#       <th id="T_c0cf8_level0_col5" class="col_heading level0 col5" >jacc_class0</th>
#       <th id="T_c0cf8_level0_col6" class="col_heading level0 col6" >jacc_class1</th>
#       <th id="T_c0cf8_level0_col7" class="col_heading level0 col7" >mIoU</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0cf8_level0_row0" class="row_heading level0 row0" >27</th>
#       <td id="T_c0cf8_row0_col0" class="data row0 col0" >False</td>
#       <td id="T_c0cf8_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_c0cf8_row0_col2" class="data row0 col2" >dino</td>
#       <td id="T_c0cf8_row0_col3" class="data row0 col3" >6.000000</td>
#       <td id="T_c0cf8_row0_col4" class="data row0 col4" >crf_multi_region</td>
#       <td id="T_c0cf8_row0_col5" class="data row0 col5" >0.914907</td>
#       <td id="T_c0cf8_row0_col6" class="data row0 col6" >0.050591</td>
#       <td id="T_c0cf8_row0_col7" class="data row0 col7" >0.482749</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row1" class="row_heading level0 row1" >25</th>
#       <td id="T_c0cf8_row1_col0" class="data row1 col0" >False</td>
#       <td id="T_c0cf8_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_c0cf8_row1_col2" class="data row1 col2" >dino</td>
#       <td id="T_c0cf8_row1_col3" class="data row1 col3" >6.000000</td>
#       <td id="T_c0cf8_row1_col4" class="data row1 col4" >crf_segmaps</td>
#       <td id="T_c0cf8_row1_col5" class="data row1 col5" >0.397322</td>
#       <td id="T_c0cf8_row1_col6" class="data row1 col6" >0.035176</td>
#       <td id="T_c0cf8_row1_col7" class="data row1 col7" >0.216249</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_c0cf8_row2_col0" class="data row2 col0" >False</td>
#       <td id="T_c0cf8_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_c0cf8_row2_col2" class="data row2 col2" >dino_ssd1</td>
#       <td id="T_c0cf8_row2_col3" class="data row2 col3" >15.000000</td>
#       <td id="T_c0cf8_row2_col4" class="data row2 col4" >crf_multi_region</td>
#       <td id="T_c0cf8_row2_col5" class="data row2 col5" >0.914620</td>
#       <td id="T_c0cf8_row2_col6" class="data row2 col6" >0.029118</td>
#       <td id="T_c0cf8_row2_col7" class="data row2 col7" >0.471869</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row3" class="row_heading level0 row3" >22</th>
#       <td id="T_c0cf8_row3_col0" class="data row3 col0" >False</td>
#       <td id="T_c0cf8_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_c0cf8_row3_col2" class="data row3 col2" >dino_ssd1</td>
#       <td id="T_c0cf8_row3_col3" class="data row3 col3" >6.000000</td>
#       <td id="T_c0cf8_row3_col4" class="data row3 col4" >crf_multi_region</td>
#       <td id="T_c0cf8_row3_col5" class="data row3 col5" >0.899945</td>
#       <td id="T_c0cf8_row3_col6" class="data row3 col6" >0.059585</td>
#       <td id="T_c0cf8_row3_col7" class="data row3 col7" >0.479765</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row4" class="row_heading level0 row4" >23</th>
#       <td id="T_c0cf8_row4_col0" class="data row4 col0" >False</td>
#       <td id="T_c0cf8_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_c0cf8_row4_col2" class="data row4 col2" >dino_ssd1</td>
#       <td id="T_c0cf8_row4_col3" class="data row4 col3" >6.000000</td>
#       <td id="T_c0cf8_row4_col4" class="data row4 col4" >crf_segmaps</td>
#       <td id="T_c0cf8_row4_col5" class="data row4 col5" >0.961593</td>
#       <td id="T_c0cf8_row4_col6" class="data row4 col6" >0.127043</td>
#       <td id="T_c0cf8_row4_col7" class="data row4 col7" >0.544318</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_c0cf8_row5_col0" class="data row5 col0" >False</td>
#       <td id="T_c0cf8_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_c0cf8_row5_col2" class="data row5 col2" >dino_ssd1</td>
#       <td id="T_c0cf8_row5_col3" class="data row5 col3" >15.000000</td>
#       <td id="T_c0cf8_row5_col4" class="data row5 col4" >crf_segmaps</td>
#       <td id="T_c0cf8_row5_col5" class="data row5 col5" >0.921120</td>
#       <td id="T_c0cf8_row5_col6" class="data row5 col6" >0.148059</td>
#       <td id="T_c0cf8_row5_col7" class="data row5 col7" >0.534590</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_c0cf8_row6_col0" class="data row6 col0" >False</td>
#       <td id="T_c0cf8_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_c0cf8_row6_col2" class="data row6 col2" >dino_ssd2</td>
#       <td id="T_c0cf8_row6_col3" class="data row6 col3" >15.000000</td>
#       <td id="T_c0cf8_row6_col4" class="data row6 col4" >crf_multi_region</td>
#       <td id="T_c0cf8_row6_col5" class="data row6 col5" >0.916690</td>
#       <td id="T_c0cf8_row6_col6" class="data row6 col6" >0.029804</td>
#       <td id="T_c0cf8_row6_col7" class="data row6 col7" >0.473247</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_c0cf8_row7_col0" class="data row7 col0" >False</td>
#       <td id="T_c0cf8_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_c0cf8_row7_col2" class="data row7 col2" >dino_ssd2</td>
#       <td id="T_c0cf8_row7_col3" class="data row7 col3" >15.000000</td>
#       <td id="T_c0cf8_row7_col4" class="data row7 col4" >crf_multi_region</td>
#       <td id="T_c0cf8_row7_col5" class="data row7 col5" >0.924374</td>
#       <td id="T_c0cf8_row7_col6" class="data row7 col6" >0.040291</td>
#       <td id="T_c0cf8_row7_col7" class="data row7 col7" >0.482332</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row8" class="row_heading level0 row8" >24</th>
#       <td id="T_c0cf8_row8_col0" class="data row8 col0" >False</td>
#       <td id="T_c0cf8_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_c0cf8_row8_col2" class="data row8 col2" >dino_ssd2</td>
#       <td id="T_c0cf8_row8_col3" class="data row8 col3" >6.000000</td>
#       <td id="T_c0cf8_row8_col4" class="data row8 col4" >crf_multi_region</td>
#       <td id="T_c0cf8_row8_col5" class="data row8 col5" >0.896431</td>
#       <td id="T_c0cf8_row8_col6" class="data row8 col6" >0.053178</td>
#       <td id="T_c0cf8_row8_col7" class="data row8 col7" >0.474805</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row9" class="row_heading level0 row9" >26</th>
#       <td id="T_c0cf8_row9_col0" class="data row9 col0" >False</td>
#       <td id="T_c0cf8_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_c0cf8_row9_col2" class="data row9 col2" >dino_ssd2</td>
#       <td id="T_c0cf8_row9_col3" class="data row9 col3" >6.000000</td>
#       <td id="T_c0cf8_row9_col4" class="data row9 col4" >crf_segmaps</td>
#       <td id="T_c0cf8_row9_col5" class="data row9 col5" >0.914976</td>
#       <td id="T_c0cf8_row9_col6" class="data row9 col6" >0.036402</td>
#       <td id="T_c0cf8_row9_col7" class="data row9 col7" >0.475689</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row10" class="row_heading level0 row10" >5</th>
#       <td id="T_c0cf8_row10_col0" class="data row10 col0" >False</td>
#       <td id="T_c0cf8_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_c0cf8_row10_col2" class="data row10 col2" >dino_ssd2</td>
#       <td id="T_c0cf8_row10

# %%
df_by_eval[(False, 0.5)]
# styled_df = df_by_eval[(False, 0.5)].style.apply(bold_rows, column='jacc_class1', sign=">", value=0.007, axis=1)
# styled_df
# Out:
#     eval_per_image  iou_thresh   features  n_clusters        prediction  \
# 11           False         0.5       dino          15  crf_multi_region
# 8            False         0.5       dino          15       crf_segmaps
# 0            False         0.5  dino_ssd1          15  crf_multi_region
# 2            False         0.5  dino_ssd1          15       crf_segmaps
# 7            False         0.5  dino_ssd2          15  crf_multi_region
# 5            False         0.5  dino_ssd2          15       crf_segmaps
#
#     jacc_class0  jacc_class1      mIoU
# 11     0.576099     0.005496  0.290798
# 8      0.522603     0.007284  0.264943
# 0      0.700100     0.001568  0.350834
# 2      0.659396     0.004014  0.331705
# 7      0.752283     0.001053  0.376668
# 5      0.695406     0.006239  0.350823

# %%
df_by_eval[(True, 0.0)]
styled_df = df_by_eval[(True, 0.0)].style.apply(bold_rows, column='jacc_class1', sign=">", value=0.59, axis=1)
styled_df
# Out:
# <style type="text/css">
# #T_6a46c_row4_col0, #T_6a46c_row4_col1, #T_6a46c_row4_col2, #T_6a46c_row4_col3, #T_6a46c_row4_col4, #T_6a46c_row4_col5, #T_6a46c_row4_col6, #T_6a46c_row4_col7 {
#   font-weight: bold;
# }
# </style>
# <table id="T_6a46c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a46c_level0_col0" class="col_heading level0 col0" >eval_per_image</th>
#       <th id="T_6a46c_level0_col1" class="col_heading level0 col1" >iou_thresh</th>
#       <th id="T_6a46c_level0_col2" class="col_heading level0 col2" >features</th>
#       <th id="T_6a46c_level0_col3" class="col_heading level0 col3" >n_clusters</th>
#       <th id="T_6a46c_level0_col4" class="col_heading level0 col4" >prediction</th>
#       <th id="T_6a46c_level0_col5" class="col_heading level0 col5" >jacc_class0</th>
#       <th id="T_6a46c_level0_col6" class="col_heading level0 col6" >jacc_class1</th>
#       <th id="T_6a46c_level0_col7" class="col_heading level0 col7" >mIoU</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a46c_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_6a46c_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_6a46c_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_6a46c_row0_col2" class="data row0 col2" >dino</td>
#       <td id="T_6a46c_row0_col3" class="data row0 col3" >15</td>
#       <td id="T_6a46c_row0_col4" class="data row0 col4" >crf_multi_region</td>
#       <td id="T_6a46c_row0_col5" class="data row0 col5" >0.953321</td>
#       <td id="T_6a46c_row0_col6" class="data row0 col6" >0.236096</td>
#       <td id="T_6a46c_row0_col7" class="data row0 col7" >0.594708</td>
#     </tr>
#     <tr>
#       <th id="T_6a46c_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_6a46c_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_6a46c_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_6a46c_row1_col2" class="data row1 col2" >dino</td>
#       <td id="T_6a46c_row1_col3" class="data row1 col3" >15</td>
#       <td id="T_6a46c_row1_col4" class="data row1 col4" >crf_segmaps</td>
#       <td id="T_6a46c_row1_col5" class="data row1 col5" >0.913491</td>
#       <td id="T_6a46c_row1_col6" class="data row1 col6" >0.165103</td>
#       <td id="T_6a46c_row1_col7" class="data row1 col7" >0.539297</td>
#     </tr>
#     <tr>
#       <th id="T_6a46c_level0_row2" class="row_heading level0 row2" >16</th>
#       <td id="T_6a46c_row2_col0" class="data row2 col0" >True</td>
#       <td id="T_6a46c_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_6a46c_row2_col2" class="data row2 col2" >dino_ssd1</td>
#       <td id="T_6a46c_row2_col3" class="data row2 col3" >15</td>
#       <td id="T_6a46c_row2_col4" class="data row2 col4" >crf_multi_region</td>
#       <td id="T_6a46c_row2_col5" class="data row2 col5" >0.983943</td>
#       <td id="T_6a46c_row2_col6" class="data row2 col6" >0.537348</td>
#       <td id="T_6a46c_row2_col7" class="data row2 col7" >0.760646</td>
#     </tr>
#     <tr>
#       <th id="T_6a46c_level0_row3" class="row_heading level0 row3" >21</th>
#       <td id="T_6a46c_row3_col0" class="data row3 col0" >True</td>
#       <td id="T_6a46c_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_6a46c_row3_col2" class="data row3 col2" >dino_ssd1</td>
#       <td id="T_6a46c_row3_col3" class="data row3 col3" >15</td>
#       <td id="T_6a46c_row3_col4" class="data row3 col4" >crf_segmaps</td>
#       <td id="T_6a46c_row3_col5" class="data row3 col5" >0.949850</td>
#       <td id="T_6a46c_row3_col6" class="data row3 col6" >0.290895</td>
#       <td id="T_6a46c_row3_col7" class="data row3 col7" >0.620372</td>
#     </tr>
#     <tr>
#       <th id="T_6a46c_level0_row4" class="row_heading level0 row4" >15</th>
#       <td id="T_6a46c_row4_col0" class="data row4 col0" >True</td>
#       <td id="T_6a46c_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_6a46c_row4_col2" class="data row4 col2" >dino_ssd2</td>
#       <td id="T_6a46c_row4_col3" class="data row4 col3" >15</td>
#       <td id="T_6a46c_row4_col4" class="data row4 col4" >crf_multi_region</td>
#       <td id="T_6a46c_row4_col5" class="data row4 col5" >0.986232</td>
#       <td id="T_6a46c_row4_col6" class="data row4 col6" >0.590251</td>
#       <td id="T_6a46c_row4_col7" class="data row4 col7" >0.788242</td>
#     </tr>
#     <tr>
#       <th id="T_6a46c_level0_row5" class="row_heading level0 row5" >18</th>
#       <td id="T_6a46c_row5_col0" class="data row5 col0" >True</td>
#       <td id="T_6a46c_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_6a46c_row5_col2" class="data row5 col2" >dino_ssd2</td>
#       <td id="T_6a46c_row5_col3" class="data row5 col3" >15</td>
#       <td id="T_6a46c_row5_col4" class="data row5 col4" >crf_segmaps</td>
#       <td id="T_6a46c_row5_col5" class="data row5 col5" >0.909543</td>
#       <td id="T_6a46c_row5_col6" class="data row5 col6" >0.196248</td>
#       <td id="T_6a46c_row5_col7" class="data row5 col7" >0.552896</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_by_eval[(True, 0.5)]
styled_df = df_by_eval[(True, 0.5)].style.apply(bold_rows, column='jacc_class1', sign=">", value=0.59, axis=1)
styled_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_d0c61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0c61_level0_col0" class="col_heading level0 col0" >eval_per_image</th>
#       <th id="T_d0c61_level0_col1" class="col_heading level0 col1" >iou_thresh</th>
#       <th id="T_d0c61_level0_col2" class="col_heading level0 col2" >features</th>
#       <th id="T_d0c61_level0_col3" class="col_heading level0 col3" >n_clusters</th>
#       <th id="T_d0c61_level0_col4" class="col_heading level0 col4" >prediction</th>
#       <th id="T_d0c61_level0_col5" class="col_heading level0 col5" >jacc_class0</th>
#       <th id="T_d0c61_level0_col6" class="col_heading level0 col6" >jacc_class1</th>
#       <th id="T_d0c61_level0_col7" class="col_heading level0 col7" >mIoU</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0c61_level0_row0" class="row_heading level0 row0" >23</th>
#       <td id="T_d0c61_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_d0c61_row0_col1" class="data row0 col1" >0.500000</td>
#       <td id="T_d0c61_row0_col2" class="data row0 col2" >dino</td>
#       <td id="T_d0c61_row0_col3" class="data row0 col3" >15</td>
#       <td id="T_d0c61_row0_col4" class="data row0 col4" >crf_multi_region</td>
#       <td id="T_d0c61_row0_col5" class="data row0 col5" >0.719467</td>
#       <td id="T_d0c61_row0_col6" class="data row0 col6" >0.031927</td>
#       <td id="T_d0c61_row0_col7" class="data row0 col7" >0.375697</td>
#     </tr>
#     <tr>
#       <th id="T_d0c61_level0_row1" class="row_heading level0 row1" >17</th>
#       <td id="T_d0c61_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_d0c61_row1_col1" class="data row1 col1" >0.500000</td>
#       <td id="T_d0c61_row1_col2" class="data row1 col2" >dino</td>
#       <td id="T_d0c61_row1_col3" class="data row1 col3" >15</td>
#       <td id="T_d0c61_row1_col4" class="data row1 col4" >crf_segmaps</td>
#       <td id="T_d0c61_row1_col5" class="data row1 col5" >0.658805</td>
#       <td id="T_d0c61_row1_col6" class="data row1 col6" >0.028191</td>
#       <td id="T_d0c61_row1_col7" class="data row1 col7" >0.343498</td>
#     </tr>
#     <tr>
#       <th id="T_d0c61_level0_row2" class="row_heading level0 row2" >13</th>
#       <td id="T_d0c61_row2_col0" class="data row2 col0" >True</td>
#       <td id="T_d0c61_row2_col1" class="data row2 col1" >0.500000</td>
#       <td id="T_d0c61_row2_col2" class="data row2 col2" >dino_ssd1</td>
#       <td id="T_d0c61_row2_col3" class="data row2 col3" >15</td>
#       <td id="T_d0c61_row2_col4" class="data row2 col4" >crf_multi_region</td>
#       <td id="T_d0c61_row2_col5" class="data row2 col5" >0.919400</td>
#       <td id="T_d0c61_row2_col6" class="data row2 col6" >0.164296</td>
#       <td id="T_d0c61_row2_col7" class="data row2 col7" >0.541848</td>
#     </tr>
#     <tr>
#       <th id="T_d0c61_level0_row3" class="row_heading level0 row3" >19</th>
#       <td id="T_d0c61_row3_col0" class="data row3 col0" >True</td>
#       <td id="T_d0c61_row3_col1" class="data row3 col1" >0.500000</td>
#       <td id="T_d0c61_row3_col2" class="data row3 col2" >dino_ssd1</td>
#       <td id="T_d0c61_row3_col3" class="data row3 col3" >15</td>
#       <td id="T_d0c61_row3_col4" class="data row3 col4" >crf_segmaps</td>
#       <td id="T_d0c61_row3_col5" class="data row3 col5" >0.810194</td>
#       <td id="T_d0c61_row3_col6" class="data row3 col6" >0.052468</td>
#       <td id="T_d0c61_row3_col7" class="data row3 col7" >0.431331</td>
#     </tr>
#     <tr>
#       <th id="T_d0c61_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_d0c61_row4_col0" class="data row4 col0" >True</td>
#       <td id="T_d0c61_row4_col1" class="data row4 col1" >0.500000</td>
#       <td id="T_d0c61_row4_col2" class="data row4 col2" >dino_ssd2</td>
#       <td id="T_d0c61_row4_col3" class="data row4 col3" >15</td>
#       <td id="T_d0c61_row4_col4" class="data row4 col4" >crf_multi_region</td>
#       <td id="T_d0c61_row4_col5" class="data row4 col5" >0.938911</td>
#       <td id="T_d0c61_row4_col6" class="data row4 col6" >0.218499</td>
#       <td id="T_d0c61_row4_col7" class="data row4 col7" >0.578705</td>
#     </tr>
#     <tr>
#       <th id="T_d0c61_level0_row5" class="row_heading level0 row5" >22</th>
#       <td id="T_d0c61_row5_col0" class="data row5 col0" >True</td>
#       <td id="T_d0c61_row5_col1" class="data row5 col1" >0.500000</td>
#       <td id="T_d0c61_row5_col2" class="data row5 col2" >dino_ssd2</td>
#       <td id="T_d0c61_row5_col3" class="data row5 col3" >15</td>
#       <td id="T_d0c61_row5_col4" class="data row5 col4" >crf_segmaps</td>
#       <td id="T_d0c61_row5_col5" class="data row5 col5" >0.762091</td>
#       <td id="T_d0c61_row5_col6" class="data row5 col6" >0.026661</td>
#       <td id="T_d0c61_row5_col7" class="data row5 col7" >0.394376</td>
#     </tr>
#   </tbody>
# </table>
