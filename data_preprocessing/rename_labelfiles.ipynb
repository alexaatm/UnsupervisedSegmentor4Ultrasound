# %%
import os
from tqdm import tqdm
import numpy as np
from PIL import Image

# %%
VOLUME_SLICES="C:/Users/Tmenova/personal/tum/thesis/initial-data/new_datasets/CAROTID_MUTINFO/val/images"
SEGMENTATION_SLICES="C:/Users/Tmenova/personal/tum/thesis/initial-data/new_datasets/CAROTID_MUTINFO/val/labels"

# %%
def rename(to_rename_folder, target_name_folder):
    for old_file, target_file in zip(sorted(os.listdir(to_rename_folder)), sorted(os.listdir(target_name_folder))):
        old_extention = os.path.splitext(old_file)[1]
        target_name = os.path.splitext(target_file)[0]

        new_name = target_name + old_extention
        new_path = os.path.join(to_rename_folder, new_name)

        old_path = os.path.join(to_rename_folder, old_file)

        print(f'Old name: {old_file}, new name: {new_name}')

        os.rename(old_path, new_path)

# %%
# rename segm file names to match volume file names
image_folder = os.path.join(VOLUME_SLICES)
segm_folder = os.path.join(SEGMENTATION_SLICES)
rename(segm_folder, image_folder)
# Out:
# Old name: label 1.png, new name: ultrasonix_test.png
# Old name: label 1001.png, new name: ultrasonix_test001.png
# Old name: label 1002.png, new name: ultrasonix_test002.png
# Old name: label 1003.png, new name: ultrasonix_test003.png
# Old name: label 1004.png, new name: ultrasonix_test004.png
# Old name: label 1005.png, new name: ultrasonix_test005.png
# Old name: label 1006.png, new name: ultrasonix_test006.png
# Old name: label 1007.png, new name: ultrasonix_test007.png
# Old name: label 1008.png, new name: ultrasonix_test008.png
# Old name: label 1009.png, new name: ultrasonix_test009.png
# Old name: label 1010.png, new name: ultrasonix_test010.png
# Old name: label 1011.png, new name: ultrasonix_test011.png
# Old name: label 1012.png, new name: ultrasonix_test012.png
# Old name: label 1013.png, new name: ultrasonix_test013.png
# Old name: label 1014.png, new name: ultrasonix_test014.png
# Old name: label 1015.png, new name: ultrasonix_test015.png
# Old name: label 1016.png, new name: ultrasonix_test016.png
# Old name: label 1017.png, new name: ultrasonix_test017.png
# Old name: label 1018.png, new name: ultrasonix_test018.png
# Old name: label 1019.png, new name: ultrasonix_test019.png
# Old name: label 1020.png, new name: ultrasonix_test020.png
# Old name: label 1021.png, new name: ultrasonix_test021.png
# Old name: label 1022.png, new name: ultrasonix_test022.png
# Old name: label 1023.png, new name: ultrasonix_test023.png
# Old name: label 1024.png, new name: ultrasonix_test024.png
# Old name: label 1025.png, new name: ultrasonix_test025.png
# Old name: label 1026.png, new name: ultrasonix_test026.png
# Old name: label 1027.png, new name: ultrasonix_test027.png
# Old name: label 1028.png, new name: ultrasonix_test028.png
# Old name: label 1029.png, new name: ultrasonix_test029.png
# Old name: label 1030.png, new name: ultrasonix_test030.png
# Old name: label 1031.png, new name: ultrasonix_test031.png
# Old name: label 1032.png, new name: ultrasonix_test032.png
# Old name: label 1033.png, new name: ultrasonix_test033.png
# Old name: label 1034.png, new name: ultrasonix_test034.png
# Old name: label 1035.png, new name: ultrasonix_test035.png
# Old name: label 1036.png, new name: ultrasonix_test036.png
# Old name: label 1037.png, new name: ultrasonix_test037.png
# Old name: label 1038.png, new name: ultrasonix_test038.png
# Old name: label 1039.png, new name: ultrasonix_test039.png
# Old name: label 1040.png, new name: ultrasonix_test040.png
# Old name: label 1041.png, new name: ultrasonix_test041.png
# Old name: label 1042.png, new name: ultrasonix_test042.png
# Old name: label 1043.png, new name: ultrasonix_test043.png
# Old name: label 1044.png, new name: ultrasonix_test044.png
# Old name: label 1045.png, new name: ultrasonix_test045.png
# Old name: label 1046.png, new name: ultrasonix_test046.png
# Old name: label 1047.png, new name: ultrasonix_test047.png
# Old name: label 1048.png, new name: ultrasonix_test048.png
# Old name: label 1049.png, new name: ultrasonix_test049.png
# Old name: label 1050.png, new name: ultrasonix_test050.png
# Old name: label 1051.png, new name: ultrasonix_test051.png
# Old name: label 1052.png, new name: ultrasonix_test052.png
# Old name: label 1053.png, new name: ultrasonix_test053.png
# Old name: label 1054.png, new name: ultrasonix_test054.png
# Old name: label 1055.png, new name: ultrasonix_test055.png
# Old name: label 1056.png, new name: ultrasonix_test056.png
# Old name: label 1057.png, new name: ultrasonix_test057.png
# Old name: label 1058.png, new name: ultrasonix_test058.png
# Old name: label 1059.png, new name: ultrasonix_test059.png
# Old name: label 1060.png, new name: ultrasonix_test060.png
# Old name: label 1061.png, new name: ultrasonix_test061.png
# Old name: label 1062.png, new name: ultrasonix_test062.png
# Old name: label 1063.png, new name: ultrasonix_test063.png
# Old name: label 1064.png, new name: ultrasonix_test064.png
# Old name: label 1065.png, new name: ultrasonix_test065.png
# Old name: label 1066.png, new name: ultrasonix_test066.png
# Old name: label 1067.png, new name: ultrasonix_test067.png
# Old name: label 1068.png, new name: ultrasonix_test068.png
# Old name: label 1069.png, new name: ultrasonix_test069.png
# Old name: label 1070.png, new name: ultrasonix_test070.png
# Old name: label 1071.png, new name: ultrasonix_test071.png
# Old name: label 1072.png, new name: ultrasonix_test072.png
# Old name: label 1073.png, new name: ultrasonix_test073.png
# Old name: label 1074.png, new name: ultrasonix_test074.png
# Old name: label 1075.png, new name: ultrasonix_test075.png
# Old name: label 1076.png, new name: ultrasonix_test076.png
# Old name: label 1077.png, new name: ultrasonix_test077.png
# Old name: label 1078.png, new name: ultrasonix_test078.png
# Old name: label 1079.png, new name: ultrasonix_test079.png
# Old name: label 1080.png, new name: ultrasonix_test080.png
# Old name: label 1081.png, new name: ultrasonix_test081.png
# Old name: label 1082.png, new name: ultrasonix_test082.png
# Old name: label 1083.png, new name: ultrasonix_test083.png
# Old name: label 1084.png, new name: ultrasonix_test084.png
# Old name: label 1085.png, new name: ultrasonix_test085.png
# Old name: label 1086.png, new name: ultrasonix_test086.png
# Old name: label 1087.png, new name: ultrasonix_test087.png
# Old name: label 1088.png, new name: ultrasonix_test088.png
# Old name: label 1089.png, new name: ultrasonix_test089.png
# Old name: label 1090.png, new name: ultrasonix_test090.png
# Old name: label 1091.png, new name: ultrasonix_test091.png
# Old name: label 1092.png, new name: ultrasonix_test092.png
# Old name: label 1093.png, new name: ultrasonix_test093.png
# Old name: label 1094.png, new name: ultrasonix_test094.png
# Old name: label 1095.png, new name: ultrasonix_test095.png
# Old name: label 1096.png, new name: ultrasonix_test096.png
# Old name: label 1097.png, new name: ultrasonix_test097.png
# Old name: label 1098.png, new name: ultrasonix_test098.png
# Old name: label 1099.png, new name: ultrasonix_test099.png
# Old name: label 1100.png, new name: ultrasonix_test100.png
# Old name: label 1101.png, new name: ultrasonix_test101.png
# Old name: label 1102.png, new name: ultrasonix_test102.png
# Old name: label 1103.png, new name: ultrasonix_test103.png
# Old name: label 1104.png, new name: ultrasonix_test104.png
# Old name: label 1105.png, new name: ultrasonix_test105.png
# Old name: label 1106.png, new name: ultrasonix_test106.png
# Old name: label 1107.png, new name: ultrasonix_test107.png
# Old name: label 1108.png, new name: ultrasonix_test108.png
# Old name: label 1109.png, new name: ultrasonix_test109.png
# Old name: label 1110.png, new name: ultrasonix_test110.png
# Old name: label 1111.png, new name: ultrasonix_test111.png
# Old name: label 1112.png, new name: ultrasonix_test112.png
# Old name: label 1113.png, new name: ultrasonix_test113.png
# Old name: label 1114.png, new name: ultrasonix_test114.png
# Old name: label 1115.png, new name: ultrasonix_test115.png
# Old name: label 1116.png, new name: ultrasonix_test116.png
# Old name: label 1117.png, new name: ultrasonix_test117.png
# Old name: label 1118.png, new name: ultrasonix_test118.png
# Old name: label 1119.png, new name: ultrasonix_test119.png
# Old name: label 1120.png, new name: ultrasonix_test120.png
# Old name: label 1121.png, new name: ultrasonix_test121.png
# Old name: label 1122.png, new name: ultrasonix_test122.png
# Old name: label 1123.png, new name: ultrasonix_test123.png
# Old name: label 1124.png, new name: ultrasonix_test124.png
# Old name: label 1125.png, new name: ultrasonix_test125.png
# Old name: label 1126.png, new name: ultrasonix_test126.png
# Old name: label 1127.png, new name: ultrasonix_test127.png
# Old name: label 1128.png, new name: ultrasonix_test128.png
# Old name: label 1129.png, new name: ultrasonix_test129.png
# Old name: label 1130.png, new name: ultrasonix_test130.png
# Old name: label 1131.png, new name: ultrasonix_test131.png
# Old name: label 1132.png, new name: ultrasonix_test132.png
# Old name: label 1133.png, new name: ultrasonix_test133.png
# Old name: label 1134.png, new name: ultrasonix_test134.png
# Old name: label 1135.png, new name: ultrasonix_test135.png
# Old name: label 1136.png, new name: ultrasonix_test136.png
# Old name: label 1137.png, new name: ultrasonix_test137.png
# Old name: label 1138.png, new name: ultrasonix_test138.png
# Old name: label 1139.png, new name: ultrasonix_test139.png
# Old name: label 1140.png, new name: ultrasonix_test140.png
# Old name: label 1141.png, new name: ultrasonix_test141.png
# Old name: label 1142.png, new name: ultrasonix_test142.png
# Old name: label 1143.png, new name: ultrasonix_test143.png
# Old name: label 1144.png, new name: ultrasonix_test144.png
# Old name: label 1145.png, new name: ultrasonix_test145.png
# Old name: label 1146.png, new name: ultrasonix_test146.png
# Old name: label 1147.png, new name: ultrasonix_test147.png
# Old name: label 1148.png, new name: ultrasonix_test148.png
# Old name: label 1149.png, new name: ultrasonix_test149.png
# Old name: label 1150.png, new name: ultrasonix_test150.png
# Old name: label 1151.png, new name: ultrasonix_test151.png
# Old name: label 1152.png, new name: ultrasonix_test152.png
# Old name: label 1153.png, new name: ultrasonix_test153.png
# Old name: label 1154.png, new name: ultrasonix_test154.png
# Old name: label 1155.png, new name: ultrasonix_test155.png
# Old name: label 1156.png, new name: ultrasonix_test156.png
# Old name: label 1157.png, new name: ultrasonix_test157.png
# Old name: label 1158.png, new name: ultrasonix_test158.png
# Old name: label 1159.png, new name: ultrasonix_test159.png
# Old name: label 1160.png, new name: ultrasonix_test160.png
# Old name: label 1161.png, new name: ultrasonix_test161.png
# Old name: label 1162.png, new name: ultrasonix_test162.png
# Old name: label 1163.png, new name: ultrasonix_test163.png
# Old name: label 1164.png, new name: ultrasonix_test164.png
# Old name: label 1165.png, new name: ultrasonix_test165.png
# Old name: label 1166.png, new name: ultrasonix_test166.png
# Old name: label 1167.png, new name: ultrasonix_test167.png
# Old name: label 1168.png, new name: ultrasonix_test168.png
# Old name: label 1169.png, new name: ultrasonix_test169.png
# Old name: label 1170.png, new name: ultrasonix_test170.png
# Old name: label 1171.png, new name: ultrasonix_test171.png
# Old name: label 1172.png, new name: ultrasonix_test172.png
# Old name: label 1173.png, new name: ultrasonix_test173.png
# Old name: label 1174.png, new name: ultrasonix_test174.png
# Old name: label 1175.png, new name: ultrasonix_test175.png
# Old name: label 1176.png, new name: ultrasonix_test176.png
# Old name: label 1177.png, new name: ultrasonix_test177.png
# Old name: label 1178.png, new name: ultrasonix_test178.png
# Old name: label 1179.png, new name: ultrasonix_test179.png
# Old name: label 1180.png, new name: ultrasonix_test180.png
# Old name: label 1181.png, new name: ultrasonix_test181.png
# Old name: label 1182.png, new name: ultrasonix_test182.png
# Old name: label 1183.png, new name: ultrasonix_test183.png
# Old name: label 1184.png, new name: ultrasonix_test184.png
# Old name: label 1185.png, new name: ultrasonix_test185.png
# Old name: label 1186.png, new name: ultrasonix_test186.png
# Old name: label 1187.png, new name: ultrasonix_test187.png
# Old name: label 1188.png, new name: ultrasonix_test188.png
# Old name: label 1189.png, new name: ultrasonix_test189.png
# Old name: label 1190.png, new name: ultrasonix_test190.png
# Old name: label 1191.png, new name: ultrasonix_test191.png
# Old name: label 1192.png, new name: ultrasonix_test192.png
# Old name: label 1193.png, new name: ultrasonix_test193.png
# Old name: label 1194.png, new name: ultrasonix_test194.png
# Old name: label 1195.png, new name: ultrasonix_test195.png
# Old name: label 1196.png, new name: ultrasonix_test196.png
# Old name: label 1197.png, new name: ultrasonix_test197.png
# Old name: label 1198.png, new name: ultrasonix_test198.png
# Old name: label 1199.png, new name: ultrasonix_test199.png
# Old name: label 1200.png, new name: ultrasonix_test200.png
# Old name: label 1201.png, new name: ultrasonix_test201.png
# Old name: label 1202.png, new name: ultrasonix_test202.png
# Old name: label 1203.png, new name: ultrasonix_test203.png
# Old name: label 1204.png, new name: ultrasonix_test204.png
# Old name: label 1205.png, new name: ultrasonix_test205.png
# Old name: label 1206.png, new name: ultrasonix_test206.png
# Old name: label 1207.png, new name: ultrasonix_test207.png
# Old name: label 1208.png, new name: ultrasonix_test208.png
# Old name: label 1209.png, new name: ultrasonix_test209.png
# Old name: label 1210.png, new name: ultrasonix_test210.png
# Old name: label 1211.png, new name: ultrasonix_test211.png
# Old name: label 1212.png, new name: ultrasonix_test212.png
# Old name: label 1213.png, new name: ultrasonix_test213.png
# Old name: label 1214.png, new name: ultrasonix_test214.png
# Old name: label 1215.png, new name: ultrasonix_test215.png
# Old name: label 1216.png, new name: ultrasonix_test216.png
# Old name: label 1217.png, new name: ultrasonix_test217.png
# Old name: label 1218.png, new name: ultrasonix_test218.png
# Old name: label 1219.png, new name: ultrasonix_test219.png
# Old name: label 1220.png, new name: ultrasonix_test220.png
# Old name: label 1221.png, new name: ultrasonix_test221.png
# Old name: label 1222.png, new name: ultrasonix_test222.png
# Old name: label 1223.png, new name: ultrasonix_test223.png
# Old name: label 1224.png, new name: ultrasonix_test224.png
# Old name: label 1225.png, new name: ultrasonix_test225.png
# Old name: label 1226.png, new name: ultrasonix_test226.png
# Old name: label 1227.png, new name: ultrasonix_test227.png
# Old name: label 1228.png, new name: ultrasonix_test228.png
# Old name: label 1229.png, new name: ultrasonix_test229.png
# Old name: label 1230.png, new name: ultrasonix_test230.png
# Old name: label 1231.png, new name: ultrasonix_test231.png
# Old name: label 1232.png, new name: ultrasonix_test232.png
# Old name: label 1233.png, new name: ultrasonix_test233.png
# Old name: label 1234.png, new name: ultrasonix_test234.png
# Old name: label 1235.png, new name: ultrasonix_test235.png
# Old name: label 1236.png, new name: ultrasonix_test236.png
# Old name: label 1237.png, new name: ultrasonix_test237.png
# Old name: label 1238.png, new name: ultrasonix_test238.png
# Old name: label 1239.png, new name: ultrasonix_test239.png
# Old name: label 1240.png, new name: ultrasonix_test240.png
# Old name: label 1241.png, new name: ultrasonix_test241.png
# Old name: label 1242.png, new name: ultrasonix_test242.png
# Old name: label 1243.png, new name: ultrasonix_test243.png
# Old name: label 1244.png, new name: ultrasonix_test244.png
# Old name: label 1245.png, new name: ultrasonix_test245.png
# Old name: label 1246.png, new name: ultrasonix_test246.png
# Old name: label 1247.png, new name: ultrasonix_test247.png
# Old name: label 1248.png, new name: ultrasonix_test248.png
# Old name: label 1249.png, new name: ultrasonix_test249.png
# Old name: label 1250.png, new name: ultrasonix_test250.png
# Old name: label 1251.png, new name: ultrasonix_test251.png
# Old name: label 1252.png, new name: ultrasonix_test252.png
# Old name: label 1253.png, new name: ultrasonix_test253.png
# Old name: label 1254.png, new name: ultrasonix_test254.png
# Old name: label 1255.png, new name: ultrasonix_test255.png
# Old name: label 1256.png, new name: ultrasonix_test256.png
# Old name: label 1257.png, new name: ultrasonix_test257.png
# Old name: label 1258.png, new name: ultrasonix_test258.png
# Old name: label 1259.png, new name: ultrasonix_test259.png
# Old name: label 1260.png, new name: ultrasonix_test260.png
# Old name: label 1261.png, new name: ultrasonix_test261.png
# Old name: label 1262.png, new name: ultrasonix_test262.png
# Old name: label 1263.png, new name: ultrasonix_test263.png
# Old name: label 1264.png, new name: ultrasonix_test264.png
# Old name: label 1265.png, new name: ultrasonix_test265.png
# Old name: label 1266.png, new name: ultrasonix_test266.png
# Old name: label 1267.png, new name: ultrasonix_test267.png
# Old name: label 1268.png, new name: ultrasonix_test268.png
# Old name: label 1269.png, new name: ultrasonix_test269.png
# Old name: label 1270.png, new name: ultrasonix_test270.png
# Old name: label 1271.png, new name: ultrasonix_test271.png
# Old name: label 1272.png, new name: ultrasonix_test272.png
# Old name: label 1273.png, new name: ultrasonix_test273.png
# Old name: label 1274.png, new name: ultrasonix_test274.png
# Old name: label 1275.png, new name: ultrasonix_test275.png
# Old name: label 1276.png, new name: ultrasonix_test276.png
# Old name: label 1277.png, new name: ultrasonix_test277.png
# Old name: label 1278.png, new name: ultrasonix_test278.png
# Old name: label 1279.png, new name: ultrasonix_test279.png
# Old name: label 1280.png, new name: ultrasonix_test280.png
# Old name: label 1281.png, new name: ultrasonix_test281.png
# Old name: label 1282.png, new name: ultrasonix_test282.png
# Old name: label 1283.png, new name: ultrasonix_test283.png
# Old name: label 1284.png, new name: ultrasonix_test284.png
# Old name: label 1285.png, new name: ultrasonix_test285.png
# Old name: label 1286.png, new name: ultrasonix_test286.png
# Old name: label 1287.png, new name: ultrasonix_test287.png
# Old name: label 1288.png, new name: ultrasonix_test288.png
# Old name: label 1289.png, new name: ultrasonix_test289.png
# Old name: label 1290.png, new name: ultrasonix_test290.png
# Old name: label 1291.png, new name: ultrasonix_test291.png
# Old name: label 1292.png, new name: ultrasonix_test292.png
# Old name: label 1293.png, new name: ultrasonix_test293.png
# Old name: label 1294.png, new name: ultrasonix_test294.png
# Old name: label 1295.png, new name: ultrasonix_test295.png
# Old name: label 1296.png, new name: ultrasonix_test296.png
# Old name: label 1297.png, new name: ultrasonix_test297.png
# Old name: label 1298.png, new name: ultrasonix_test298.png
# Old name: label 1299.png, new name: ultrasonix_test299.png
# Old name: label 1300.png, new name: ultrasonix_test300.png
# Old name: label 1301.png, new name: ultrasonix_test301.png
# Old name: label 1302.png, new name: ultrasonix_test302.png
# Old name: label 1303.png, new name: ultrasonix_test303.png
# Old name: label 1304.png, new name: ultrasonix_test304.png
# Old name: label 1305.png, new name: ultrasonix_test305.png
# Old name: label 1306.png, new name: ultrasonix_test306.png
# Old name: label 1307.png, new name: ultrasonix_test307.png
# Old name: label 1308.png, new name: ultrasonix_test308.png
# Old name: label 1309.png, new name: ultrasonix_test309.png
# Old name: label 1310.png, new name: ultrasonix_test310.png
# Old name: label 1311.png, new name: ultrasonix_test311.png
# Old name: label 1312.png, new name: ultrasonix_test312.png
# Old name: label 1313.png, new name: ultrasonix_test313.png
# Old name: label 1314.png, new name: ultrasonix_test314.png
# Old name: label 1315.png, new name: ultrasonix_test315.png
# Old name: label 1316.png, new name: ultrasonix_test316.png
# Old name: label 1317.png, new name: ultrasonix_test317.png
# Old name: label 1318.png, new name: ultrasonix_test318.png
# Old name: label 1319.png, new name: ultrasonix_test319.png
# Old name: label 1320.png, new name: ultrasonix_test320.png
# Old name: label 1321.png, new name: ultrasonix_test321.png
# Old name: label 1322.png, new name: ultrasonix_test322.png
# Old name: label 1323.png, new name: ultrasonix_test323.png
# Old name: label 1324.png, new name: ultrasonix_test324.png
# Old name: label 1325.png, new name: ultrasonix_test325.png
# Old name: label 1326.png, new name: ultrasonix_test326.png
# Old name: label 1327.png, new name: ultrasonix_test327.png
# Old name: label 1328.png, new name: ultrasonix_test328.png
# Old name: label 1329.png, new name: ultrasonix_test329.png
# Old name: label 1330.png, new name: ultrasonix_test330.png
# Old name: label 1331.png, new name: ultrasonix_test331.png
# Old name: label 1332.png, new name: ultrasonix_test332.png
# Old name: label 1333.png, new name: ultrasonix_test333.png
# Old name: label 1334.png, new name: ultrasonix_test334.png
# Old name: label 1335.png, new name: ultrasonix_test335.png
# Old name: label 1336.png, new name: ultrasonix_test336.png
# Old name: label 1337.png, new name: ultrasonix_test337.png
# Old name: label 1338.png, new name: ultrasonix_test338.png
# Old name: label 1339.png, new name: ultrasonix_test339.png
# Old name: label 1340.png, new name: ultrasonix_test340.png
# Old name: label 1341.png, new name: ultrasonix_test341.png
# Old name: label 1342.png, new name: ultrasonix_test342.png
# Old name: label 1343.png, new name: ultrasonix_test343.png
# Old name: label 1344.png, new name: ultrasonix_test344.png
# Old name: label 1345.png, new name: ultrasonix_test345.png
# Old name: label 1346.png, new name: ultrasonix_test346.png
# Old name: label 1347.png, new name: ultrasonix_test347.png
# Old name: label 1348.png, new name: ultrasonix_test348.png
# Old name: label 1349.png, new name: ultrasonix_test349.png
# Old name: label 1350.png, new name: ultrasonix_test350.png
# Old name: label 1351.png, new name: ultrasonix_test351.png
# Old name: label 1352.png, new name: ultrasonix_test352.png
# Old name: label 1353.png, new name: ultrasonix_test353.png
# Old name: label 1354.png, new name: ultrasonix_test354.png
# Old name: label 1355.png, new name: ultrasonix_test355.png
# Old name: label 1356.png, new name: ultrasonix_test356.png
# Old name: label 1357.png, new name: ultrasonix_test357.png
# Old name: label 1358.png, new name: ultrasonix_test358.png
# Old name: label 1359.png, new name: ultrasonix_test359.png
# Old name: label 1360.png, new name: ultrasonix_test360.png
# Old name: label 1361.png, new name: ultrasonix_test361.png
# Old name: label 1362.png, new name: ultrasonix_test362.png
# Old name: label 1363.png, new name: ultrasonix_test363.png
# Old name: label 1364.png, new name: ultrasonix_test364.png
# Old name: label 1365.png, new name: ultrasonix_test365.png
# Old name: label 1366.png, new name: ultrasonix_test366.png
# Old name: label 1367.png, new name: ultrasonix_test367.png
# Old name: label 1368.png, new name: ultrasonix_test368.png
# Old name: label 1369.png, new name: ultrasonix_test369.png
# Old name: label 1370.png, new name: ultrasonix_test370.png
# Old name: label 1371.png, new name: ultrasonix_test371.png
# Old name: label 1372.png, new name: ultrasonix_test372.png
# Old name: label 1373.png, new name: ultrasonix_test373.png
# Old name: label 1374.png, new name: ultrasonix_test374.png
# Old name: label 1375.png, new name: ultrasonix_test375.png
# Old name: label 1376.png, new name: ultrasonix_test376.png
# Old name: label 1377.png, new name: ultrasonix_test377.png
# Old name: label 1378.png, new name: ultrasonix_test378.png
# Old name: label 1379.png, new name: ultrasonix_test379.png
# Old name: label 1380.png, new name: ultrasonix_test380.png
# Old name: label 1381.png, new name: ultrasonix_test381.png
# Old name: label 1382.png, new name: ultrasonix_test382.png
# Old name: label 1383.png, new name: ultrasonix_test383.png
# Old name: label 1384.png, new name: ultrasonix_test384.png
# Old name: label 1385.png, new name: ultrasonix_test385.png
# Old name: label 1386.png, new name: ultrasonix_test386.png
# Old name: label 1387.png, new name: ultrasonix_test387.png
# Old name: label 1388.png, new name: ultrasonix_test388.png
# Old name: label 1389.png, new name: ultrasonix_test389.png
# Old name: label 1390.png, new name: ultrasonix_test390.png
# Old name: label 1391.png, new name: ultrasonix_test391.png
# Old name: label 1392.png, new name: ultrasonix_test392.png
# Old name: label 1393.png, new name: ultrasonix_test393.png
# Old name: label 1394.png, new name: ultrasonix_test394.png
# Old name: label 1395.png, new name: ultrasonix_test395.png
# Old name: label 1396.png, new name: ultrasonix_test396.png
# Old name: label 1397.png, new name: ultrasonix_test397.png
# Old name: label 1398.png, new name: ultrasonix_test398.png
# Old name: label 1399.png, new name: ultrasonix_test399.png
# Old name: label 1400.png, new name: ultrasonix_test400.png
# Old name: label 1401.png, new name: ultrasonix_test401.png
# Old name: label 1402.png, new name: ultrasonix_test402.png
# Old name: label 1403.png, new name: ultrasonix_test403.png
# Old name: label 1404.png, new name: ultrasonix_test404.png
# Old name: label 1405.png, new name: ultrasonix_test405.png
# Old name: label 1406.png, new name: ultrasonix_test406.png
# Old name: label 1407.png, new name: ultrasonix_test407.png
# Old name: label 1408.png, new name: ultrasonix_test408.png
# Old name: label 1409.png, new name: ultrasonix_test409.png
# Old name: label 1410.png, new name: ultrasonix_test410.png
# Old name: label 1411.png, new name: ultrasonix_test411.png
# Old name: label 1412.png, new name: ultrasonix_test412.png
# Old name: label 1413.png, new name: ultrasonix_test413.png
# Old name: label 1414.png, new name: ultrasonix_test414.png
# Old name: label 1415.png, new name: ultrasonix_test415.png
# Old name: label 1416.png, new name: ultrasonix_test416.png
# Old name: label 1417.png, new name: ultrasonix_test417.png
# Old name: label 1418.png, new name: ultrasonix_test418.png
# Old name: label 1419.png, new name: ultrasonix_test419.png
# Old name: label 1420.png, new name: ultrasonix_test420.png
# Old name: label 1421.png, new name: ultrasonix_test421.png
# Old name: label 1422.png, new name: ultrasonix_test422.png
# Old name: label 1423.png, new name: ultrasonix_test423.png
# Old name: label 1424.png, new name: ultrasonix_test424.png
# Old name: label 1425.png, new name: ultrasonix_test425.png
# Old name: label 1426.png, new name: ultrasonix_test426.png
# Old name: label 1427.png, new name: ultrasonix_test427.png
# Old name: label 1428.png, new name: ultrasonix_test428.png
# Old name: label 1429.png, new name: ultrasonix_test429.png
# Old name: label 1430.png, new name: ultrasonix_test430.png
# Old name: label 1431.png, new name: ultrasonix_test431.png
# Old name: label 1432.png, new name: ultrasonix_test432.png
# Old name: label 1433.png, new name: ultrasonix_test433.png
# Old name: label 1434.png, new name: ultrasonix_test434.png
# Old name: label 1435.png, new name: ultrasonix_test435.png
# Old name: label 1436.png, new name: ultrasonix_test436.png
# Old name: label 1437.png, new name: ultrasonix_test437.png
# Old name: label 1438.png, new name: ultrasonix_test438.png
# Old name: label 1439.png, new name: ultrasonix_test439.png
# Old name: label 1440.png, new name: ultrasonix_test440.png
# Old name: label 1441.png, new name: ultrasonix_test441.png
# Old name: label 1442.png, new name: ultrasonix_test442.png
# Old name: label 1443.png, new name: ultrasonix_test443.png
# Old name: label 1444.png, new name: ultrasonix_test444.png
# Old name: label 1445.png, new name: ultrasonix_test445.png
# Old name: label 1446.png, new name: ultrasonix_test446.png
# Old name: label 1447.png, new name: ultrasonix_test447.png
# Old name: label 1448.png, new name: ultrasonix_test448.png
# Old name: label 1449.png, new name: ultrasonix_test449.png
# Old name: label 1450.png, new name: ultrasonix_test450.png
# Old name: label 1451.png, new name: ultrasonix_test451.png
# Old name: label 1452.png, new name: ultrasonix_test452.png
# Old name: label 1453.png, new name: ultrasonix_test453.png
# Old name: label 1454.png, new name: ultrasonix_test454.png
# Old name: label 1455.png, new name: ultrasonix_test455.png
# Old name: label 1456.png, new name: ultrasonix_test456.png
# Old name: label 1457.png, new name: ultrasonix_test457.png
# Old name: label 1458.png, new name: ultrasonix_test458.png
# Old name: label 1459.png, new name: ultrasonix_test459.png
# Old name: label 1460.png, new name: ultrasonix_test460.png
# Old name: label 1461.png, new name: ultrasonix_test461.png
# Old name: label 1462.png, new name: ultrasonix_test462.png
# Old name: label 1463.png, new name: ultrasonix_test463.png
# Old name: label 1464.png, new name: ultrasonix_test464.png
# Old name: label 1465.png, new name: ultrasonix_test465.png
# Old name: label 1466.png, new name: ultrasonix_test466.png
# Old name: label 1467.png, new name: ultrasonix_test467.png
# Old name: label 1468.png, new name: ultrasonix_test468.png
# Old name: label 1469.png, new name: ultrasonix_test469.png
# Old name: label 1470.png, new name: ultrasonix_test470.png
# Old name: label 1471.png, new name: ultrasonix_test471.png
# Old name: label 1472.png, new name: ultrasonix_test472.png
# Old name: label 1473.png, new name: ultrasonix_test473.png
# Old name: label 1474.png, new name: ultrasonix_test474.png
# Old name: label 1475.png, new name: ultrasonix_test475.png
# Old name: label 1476.png, new name: ultrasonix_test476.png
# Old name: label 1477.png, new name: ultrasonix_test477.png
# Old name: label 1478.png, new name: ultrasonix_test478.png
# Old name: label 1479.png, new name: ultrasonix_test479.png
# Old name: label 1480.png, new name: ultrasonix_test480.png
# Old name: label 1481.png, new name: ultrasonix_test481.png
# Old name: label 1482.png, new name: ultrasonix_test482.png
# Old name: label 1483.png, new name: ultrasonix_test483.png
# Old name: label 1484.png, new name: ultrasonix_test484.png
# Old name: label 1485.png, new name: ultrasonix_test485.png
# Old name: label 1486.png, new name: ultrasonix_test486.png
# Old name: label 1487.png, new name: ultrasonix_test487.png
# Old name: label 1488.png, new name: ultrasonix_test488.png
# Old name: label 1489.png, new name: ultrasonix_test489.png
# Old name: label 1490.png, new name: ultrasonix_test490.png
# Old name: label 1491.png, new name: ultrasonix_test491.png
# Old name: label 1492.png, new name: ultrasonix_test492.png
# Old name: label 1493.png, new name: ultrasonix_test493.png
# Old name: label 1494.png, new name: ultrasonix_test494.png
# Old name: label 1495.png, new name: ultrasonix_test495.png
# Old name: label 1496.png, new name: ultrasonix_test496.png
# Old name: label 1497.png, new name: ultrasonix_test497.png
# Old name: label 1498.png, new name: ultrasonix_test498.png
# Old name: label 1499.png, new name: ultrasonix_test499.png
# Old name: label 1500.png, new name: ultrasonix_test500.png
# Old name: label 1501.png, new name: ultrasonix_test501.png
# Old name: label 1502.png, new name: ultrasonix_test502.png
# Old name: label 1503.png, new name: ultrasonix_test503.png
# Old name: label 1504.png, new name: ultrasonix_test504.png
# Old name: label 1505.png, new name: ultrasonix_test505.png
# Old name: label 1506.png, new name: ultrasonix_test506.png
# Old name: label 1507.png, new name: ultrasonix_test507.png
# Old name: label 1508.png, new name: ultrasonix_test508.png
# Old name: label 1509.png, new name: ultrasonix_test509.png
# Old name: label 1510.png, new name: ultrasonix_test510.png
# Old name: label 1511.png, new name: ultrasonix_test511.png
# Old name: label 1512.png, new name: ultrasonix_test512.png
# Old name: label 1513.png, new name: ultrasonix_test513.png
# Old name: label 1514.png, new name: ultrasonix_test514.png
# Old name: label 1515.png, new name: ultrasonix_test515.png
# Old name: label 1516.png, new name: ultrasonix_test516.png
# Old name: label 1517.png, new name: ultrasonix_test517.png
# Old name: label 1518.png, new name: ultrasonix_test518.png
# Old name: label 1519.png, new name: ultrasonix_test519.png
# Old name: label 1520.png, new name: ultrasonix_test520.png
# Old name: label 1521.png, new name: ultrasonix_test521.png
# Old name: label 1522.png, new name: ultrasonix_test522.png
# Old name: label 1523.png, new name: ultrasonix_test523.png
# Old name: label 1524.png, new name: ultrasonix_test524.png
# Old name: label 1525.png, new name: ultrasonix_test525.png
# Old name: label 1526.png, new name: ultrasonix_test526.png
# Old name: label 1527.png, new name: ultrasonix_test527.png
# Old name: label 1528.png, new name: ultrasonix_test528.png
# Old name: label 1529.png, new name: ultrasonix_test529.png
# Old name: label 1530.png, new name: ultrasonix_test530.png
# Old name: label 1531.png, new name: ultrasonix_test531.png
# Old name: label 1532.png, new name: ultrasonix_test532.png
# Old name: label 1533.png, new name: ultrasonix_test533.png
# Old name: label 1534.png, new name: ultrasonix_test534.png
# Old name: label 1535.png, new name: ultrasonix_test535.png
# Old name: label 1536.png, new name: ultrasonix_test536.png
# Old name: label 1537.png, new name: ultrasonix_test537.png
